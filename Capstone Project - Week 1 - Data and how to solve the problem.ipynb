# %% [markdown]
# # BARCELONA : A GOOD PLACE TO OPEN A FRENCH RESTAURANT
# # Capstone Project - The Battle of Neighborhoods (Week 1)

# %% [markdown]
# ![barcelona-cityscape-overlook-P4HU7G7-1280x640.jpg](attachment:barcelona-cityscape-overlook-P4HU7G7-1280x640.jpg)

# %% [markdown]
# ## 4/Data
#
# ### For this project I need the following data :
# #### 1/ Fousquare API Description : by using this api we will get all the venues in each neighborhood.
# #### 2/ Excel file that recap information like Borough, Zip Code, Neighborough, Latitude, Longitude, Population and Density inhabitants /km2.
#
# ![Capture%20d%E2%80%99e%CC%81cran%202021-08-06%20a%CC%80%2019.10.39.png](attachment:Capture%20d%E2%80%99e%CC%81cran%202021-08-06%20a%CC%80%2019.10.39.png)
#
# #### 3/ Wikipedia to collect qualitative information about Barcelona : https://en.wikipedia.org/wiki/Barcelona

# %% [markdown]
# ## 5/How to solve the problem
# ### To solve the problem I need:
#  - KMeans clustering
#  - Folium
#  - Matplotlib
#  - Foursquare API
#  - Pandas, Numpy, Request librairies
#  - Json
#  - One hot encoding technic
#  - Geopy geocoders  technic
#
# ### Steps to solve the problem:
#
# - Step 1: Analysis of the Excel sheet called "District Barcelona" to have an overview of the different Boroughs, Zip Code, Neighborhoods, Population and density of the population.
#
# - Step 2: Define the geographical coordinate of Barcelona.
#
# - Step 3: Create map of Barcelona using latitude and longitude values.
#
# - Step 4: Use Foursquare API, json, one hot encoding to study different venues and create a datraframe.
#
# - step 5: Set a number of clusters.
#
# - step 6: Select the best cluster.
#
# - Step 7: Select and geolocalize the city center of Barcelona : Catalonia Square.
#
# - Step 8: Use matplotlib to identify, study and exclude some Boroughs.
#
# - Step 9: Use Folium and the  dataframe to analize and select the best Borough.
